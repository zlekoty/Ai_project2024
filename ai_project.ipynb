# %%
import numpy as np

# %%
def board_map(board):
        symbol_map = {0: " ", 1: "o", 2: "x"}
        return [symbol_map[value] for value in board]
    
class TicTacToe():
    
    player = 1

    def __init__(self):
        self.b1 = np.zeros(9)
        self.b2 = np.zeros(9)
        self.b3 = np.zeros(9)
        self.b4 = np.zeros(9)
        self.b5 = np.zeros(9)
        self.b6 = np.zeros(9)
        self.b7 = np.zeros(9)
        self.b8 = np.zeros(9)
        self.b9 = np.zeros(9)
        self.B = np.zeros(9)
    
    
    def __str__(self):
        return """
                {a[0]}{a[1]}{a[2]}|{b[0]}{b[1]}{b[2]}|{c[0]}{c[1]}{c[2]}
                {a[3]}{a[4]}{a[5]}|{b[3]}{b[4]}{b[5]}|{c[3]}{c[4]}{c[5]}
                {a[6]}{a[7]}{a[8]}|{b[6]}{b[7]}{b[8]}|{c[6]}{c[7]}{c[8]}
                ------------
                {d[0]}{d[1]}{d[2]}|{e[0]}{e[1]}{e[2]}|{f[0]}{f[1]}{f[2]}
                {d[3]}{d[4]}{d[5]}|{e[3]}{e[4]}{e[5]}|{f[3]}{f[4]}{f[5]}
                {d[6]}{d[7]}{d[8]}|{e[6]}{e[7]}{e[8]}|{f[6]}{f[7]}{f[8]}
                ------------
                {g[0]}{g[1]}{g[2]}|{h[0]}{h[1]}{h[2]}|{i[0]}{i[1]}{i[2]}
                {g[3]}{g[4]}{g[5]}|{h[3]}{h[4]}{h[5]}|{i[3]}{i[4]}{i[5]}
                {g[6]}{g[7]}{g[8]}|{h[6]}{h[7]}{h[8]}|{i[6]}{i[7]}{i[8]}

                """.format(a=board_map(self.b1), b=board_map(self.b2), c=board_map(self.b3), d=board_map(self.b4), e=board_map(self.b5), f=board_map(self.b6), g=board_map(self.b7), h=board_map(self.b8), i=board_map(self.b9))
    
    def won(self):
        i=0
        for b in self.__dict__.values():
            if i>=9:
                break
            if ((b[0]==b[1]==b[2]==1) or (b[3]==b[4]==b[5]==1) or (b[6]==b[7]==b[8]==1) or
                (b[0]==b[3]==b[6]==1) or (b[1]==b[4]==b[7]==1) or (b[2]==b[5]==b[8]==1) or 
                (b[0]==b[4]==b[8]==1) or (b[2]==b[4]==b[6]==1)):
                self.B[i]=1
                i+=1
            elif ((b[0]==b[1]==b[2]==2) or (b[3]==b[4]==b[5]==2) or (b[6]==b[7]==b[8]==2) 
                or (b[0]==b[3]==b[6]==2) or (b[1]==b[4]==b[7]==2) or (b[2]==b[5]==b[8]==2)
                or (b[0]==b[4]==b[8]==2) or (b[2]==b[4]==b[6]==2)):
                self.B[i]=2
                i+=1
            else:
                i+=1
        print("B",self.B,i)
        
        if ((self.B[0]==self.B[1]==self.B[2]==1) or (self.B[3]==self.B[4]==self.B[5]==1) or (self.B[6]==self.B[7]==self.B[8]==1) or
            (self.B[0]==self.B[3]==self.B[6]==1) or (self.B[1]==self.B[4]==self.B[7]==1) or (self.B[2]==self.B[6]==self.B[8]==1) or
            (self.B[0]==self.B[4]==self.B[8]==1) or (self.B[2]==self.B[4]==self.B[6]==1)):
            return 'PLAYER1 WON'
        if ((self.B[0]==self.B[1]==self.B[2]==2) or (self.B[3]==self.B[4]==self.B[5]==2) or (self.B[6]==self.B[7]==self.B[8]==2) or
            (self.B[0]==self.B[3]==self.B[6]==2) or (self.B[1]==self.B[4]==self.B[7]==2) or (self.B[2]==self.B[6]==self.B[8]==2) or
            (self.B[0]==self.B[4]==self.B[8]==2) or (self.B[2]==self.B[4]==self.B[6]==2)):
            return 'PLAYER2 WON'
    
    def move(self,board,field):
        print(self.player,board,field)
        self.__dict__[board][field] = self.player

# %%
def board_map(board):
        symbol_map = {0: " ", 1: "o", 2: "x"}
        return [symbol_map[value] for value in board]
    
class TicTacToe():
    
    player = 1

    def __init__(self):
        self.b1 = np.zeros(9)
        self.b2 = np.zeros(9)
        self.b3 = np.zeros(9)
        self.b4 = np.zeros(9)
        self.b5 = np.zeros(9)
        self.b6 = np.zeros(9)
        self.b7 = np.zeros(9)
        self.b8 = np.zeros(9)
        self.b9 = np.zeros(9)
        self.B = np.zeros(9)
    
    
    def __str__(self):
        return """
                {a[0]}{a[1]}{a[2]}|{b[0]}{b[1]}{b[2]}|{c[0]}{c[1]}{c[2]}
                {a[3]}{a[4]}{a[5]}|{b[3]}{b[4]}{b[5]}|{c[3]}{c[4]}{c[5]}
                {a[6]}{a[7]}{a[8]}|{b[6]}{b[7]}{b[8]}|{c[6]}{c[7]}{c[8]}
                ------------
                {d[0]}{d[1]}{d[2]}|{e[0]}{e[1]}{e[2]}|{f[0]}{f[1]}{f[2]}
                {d[3]}{d[4]}{d[5]}|{e[3]}{e[4]}{e[5]}|{f[3]}{f[4]}{f[5]}
                {d[6]}{d[7]}{d[8]}|{e[6]}{e[7]}{e[8]}|{f[6]}{f[7]}{f[8]}
                ------------
                {g[0]}{g[1]}{g[2]}|{h[0]}{h[1]}{h[2]}|{i[0]}{i[1]}{i[2]}
                {g[3]}{g[4]}{g[5]}|{h[3]}{h[4]}{h[5]}|{i[3]}{i[4]}{i[5]}
                {g[6]}{g[7]}{g[8]}|{h[6]}{h[7]}{h[8]}|{i[6]}{i[7]}{i[8]}

                """.format(a=board_map(self.b1), b=board_map(self.b2), c=board_map(self.b3), d=board_map(self.b4), e=board_map(self.b5), f=board_map(self.b6), g=board_map(self.b7), h=board_map(self.b8), i=board_map(self.b9))
    
    def won(self):
        i=0
        for b in self.__dict__.values():
            if i>=9:
                break
            if ((b[0]==b[1]==b[2]==1) or (b[3]==b[4]==b[5]==1) or (b[6]==b[7]==b[8]==1) or
                (b[0]==b[3]==b[6]==1) or (b[1]==b[4]==b[7]==1) or (b[2]==b[5]==b[8]==1) or 
                (b[0]==b[4]==b[8]==1) or (b[2]==b[4]==b[6]==1)):
                self.B[i]=1
                i+=1
            elif ((b[0]==b[1]==b[2]==2) or (b[3]==b[4]==b[5]==2) or (b[6]==b[7]==b[8]==2) 
                or (b[0]==b[3]==b[6]==2) or (b[1]==b[4]==b[7]==2) or (b[2]==b[5]==b[8]==2)
                or (b[0]==b[4]==b[8]==2) or (b[2]==b[4]==b[6]==2)):
                self.B[i]=2
                i+=1
            else:
                i+=1
        print("B",self.B,i)
        
        if ((self.B[0]==self.B[1]==self.B[2]==1) or (self.B[3]==self.B[4]==self.B[5]==1) or (self.B[6]==self.B[7]==self.B[8]==1) or
            (self.B[0]==self.B[3]==self.B[6]==1) or (self.B[1]==self.B[4]==self.B[7]==1) or (self.B[2]==self.B[6]==self.B[8]==1) or
            (self.B[0]==self.B[4]==self.B[8]==1) or (self.B[2]==self.B[4]==self.B[6]==1)):
            return 'PLAYER1 WON'
        if ((self.B[0]==self.B[1]==self.B[2]==2) or (self.B[3]==self.B[4]==self.B[5]==2) or (self.B[6]==self.B[7]==self.B[8]==2) or
            (self.B[0]==self.B[3]==self.B[6]==2) or (self.B[1]==self.B[4]==self.B[7]==2) or (self.B[2]==self.B[6]==self.B[8]==2) or
            (self.B[0]==self.B[4]==self.B[8]==2) or (self.B[2]==self.B[4]==self.B[6]==2)):
            return 'PLAYER2 WON'
    
    def move(self,board,field):
        print(self.player,board,field)
        self.__dict__[board][field] = self.player

# %%
#game loop

print("""
--------ULTIMATE TIC TAC TOE-------------

Goal: 3 in a horizontal, vertical, or diagonal row.

     |     |  
  b1 |  b2 |  b3 
_____|_____|_____
     |     |     
  b4 |  b5 |  b6  
_____|_____|_____
     |     |     
  b7 |  b8 |  b9 
     |     |     
     
Each board bx contains tic-tac-toe board indexed:

     |     |  
  0  |  1  |  2 
_____|_____|_____
     |     |     
  3  |  4  |  5  
_____|_____|_____
     |     |     
  6  |  7  |  8 
     |     |     
     
Player can take board bx if they win nested tic-tac-toe there.

""")

ttt = TicTacToe()
while True:
    #human move
    ttt.player=1
    player_board = input("Enter board name [b1-b9]: ")
    player_field = input("Enter board field [0-8]: ")
    
    print(player_board,player_field)
    
    ttt.move(player_board,int(player_field))
    end = ttt.won()
    print(ttt, ttt.player)
    
    #ai move
    ttt.player=2
    
    if (end == 'PLAYER1 WON') or (end == 'PLAYER2 WON'):
        print(end)
        break
# Out:
# --------ULTIMATE TIC TAC TOE-------------
#
# Goal: 3 in a horizontal, vertical, or diagonal row.
#
#      |     |
#   b1 |  b2 |  b3
# _____|_____|_____
#      |     |
#   b4 |  b5 |  b6
# _____|_____|_____
#      |     |
#   b7 |  b8 |  b9
#      |     |
#
# Each board bx contains tic-tac-toe board indexed:
#
#      |     |
#   0  |  1  |  2
# _____|_____|_____
#      |     |
#   3  |  4  |  5
# _____|_____|_____
#      |     |
#   6  |  7  |  8
#      |     |
#
# Player can take board bx if they win nested tic-tac-toe there.
#
#
# Enter board name [b1-b9]: b1
# Enter board field [0-8]: 0
# b1 0
# 1 b1 0
# B [0. 0. 0. 0. 0. 0. 0. 0. 0.] 9
#
#                 o  |   |
#                    |   |
#                    |   |
#                 ------------
#                    |   |
#                    |   |
#                    |   |
#                 ------------
#                    |   |
#                    |   |
#                    |   |
#
#                  1
# ...
